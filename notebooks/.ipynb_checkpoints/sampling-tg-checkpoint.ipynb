# %%
import numpy as np
from cmeutils.sampling import is_equilibrated, equil_sample
import unyt as u
from unyt import Unit
import signac
import gsd.hoomd
import matplotlib.pyplot as plt

# %%
project = signac.get_project("../validation/")

# %%
for job in project.find_jobs(filter={"remove_hydrogens": True}):
    data = np.genfromtxt(job.fn("log.txt"), names=True)
    vol = data["mdcomputeThermodynamicQuantitiesvolume"]
    pe = data["mdcomputeThermodynamicQuantitiespotential_energy"]
    sample_idx = len(vol)//2
    vol_eq = is_equilibrated(vol[sample_idx:], threshold_fraction=0.10, threshold_neff=100)[0]
    pe_eq = is_equilibrated(pe[sample_idx:], threshold_fraction=0.10, threshold_neff=100)[0]
    print(vol_eq, pe_eq)
    print()
# Out:
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True
#
# True True

# %%
for job in project.find_jobs(filter={"remove_hydrogens": True}):
    data = np.genfromtxt(job.fn("log.txt"), names=True)
    vol = data["mdcomputeThermodynamicQuantitiesvolume"]
    sample_idx = len(vol)//2
    uncorr_sample, uncorr_indices, prod_start, Neff = equil_sample(
        vol[sample_idx:], threshold_fraction=0.10, threshold_neff=100
    )
    vol_nm = uncorr_sample * (job.doc.ref_length**3) * Unit(f"{job.doc.ref_length_units}**3")
    vol_cm = vol_nm.to("cm**3")
    job.doc.avg_vol = np.mean(vol_cm.value)
    job.doc.vol_std = np.std(vol_cm.value)
    #np.savetxt(job.fn("vol_sample_indices.txt"), uncorr_indices + sample_idx)
    np.savetxt(job.fn("vol_cc.txt"), vol_cm.value)
    with gsd.hoomd.open(job.fn("restart.gsd")) as traj:
        snap = traj[0]
        reduced_mass = sum(snap.particles.mass)
        mass_amu = reduced_mass * job.doc.ref_mass * Unit(job.doc.ref_mass_units)
        mass_g = mass_amu.to("g")
        job.doc.mass_g = mass_g.value
    job.doc.avg_density = job.doc.mass_g / job.doc.avg_vol
    job.doc.density_std = job.doc.mass_g / job.doc.vol_std
    job.doc.volume_sampled = True
# Out:
# 1791
# 2000
# 667
# 393
# 1997
# 2000
# 1325
# 1657
# 1997
# 1580
# 880
# 1828
# 1715
# 1936
# 1987
# 1105
# 1512
# 1116
# 893
# 1604
# 463
# 673
# 1888
# 1416

# %%
for kT, job in project.find_jobs({"remove_hydrogens": True}).groupby("kT"):
    if kT < 1.1 or kT > 2.6: continue
    job = list(job)[0]
    print(kT, job.path)
    plt.plot(kT, job.doc.avg_density, "ko")
    plt.vlines(x=1.67, ymin=1.38, ymax=1.47, ls="--", color="red")
# Out:
# 1.1 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/0c81ccd106e7cc250445e59a6a849b5f
# 1.2 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/61c22faf7b637430b7decf1c4d2546d4
# 1.3 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/6022682ba44d8e05359a408b5e5e3fb0
# 1.4 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/9d0a23f75ed11e78c19f32889f7bf10b
# 1.5 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/d36a3651496edd00b0135b7583d17f84
# 1.6 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/93d0693f832acb0c299a2df7e0b4d946
# 1.7 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/e395d49808e46b353934ae3d9989a2ef
# 1.8 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/9d6790824fad99144cb9e78eed65c759
# 1.9 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/621a83c12fc08db53cf90095862f8f3b
# 2.0 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/5f12c336b359bf46fbbab8a8bcf5b8c4
# 2.1 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/9ed68020b0249cbf0dd556ecbfa03fec
# 2.2 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/d3bde157f0ec24595df8087189e6492f
# 2.3 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/e981f8cc6ce7f1524db701cb412221d6
# 2.4 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/b451bc879838e2af036d79f59a3e82bd
# 2.5 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/fab48edbe38b9bc5b9e0bac66a39f099
# 2.6 /home/erjank_project/chrisjones/1-PPS-MSIBI/pps-msibi/validation/workspace/f2688ee8c09b1ca212a7e4d20e3894d8

# %%
len(data)
# Out:
# 8001

# %%
plt.plot(data["mdcomputeThermodynamicQuantitiesvolume"][4000:])
